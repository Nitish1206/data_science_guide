# %%
import pandas as pd

# %%
data_path=r"pandas_dataset\Loan_Data.csv"

# %% [markdown]
# ## load csv

# %%
loanData=pd.read_csv(data_path)

# %% [markdown]
# ### head shows top 5 datapoint from your dataframe

# %%
loanData.head()
# Out:
#    ID  Income_of_Applicant  Income_of_Joint_Applicant  \
# 0   1                 5849                        0.0
# 1   2                 4583                     1508.0
# 2   3                 3000                        0.0
# 3   4                 2583                     2358.0
# 4   5                 6000                        0.0
#
#    Loan_Amount_Requirement  Loan_Amount_Term  Credit_History Gender  \
# 0                      NaN             360.0             1.0   Male
# 1                    128.0             360.0             1.0   Male
# 2                     66.0             360.0             1.0   Male
# 3                    120.0             360.0             1.0   Male
# 4                    141.0             360.0             1.0   Male
#
#   Is_Married No_of_Dependents Level_of_Education IS_Self_Employed  \
# 0         No                0           Graduate               No
# 1        Yes                1           Graduate               No
# ...

# %% [markdown]
# ### read csv without header

# %%
loan_data_withoutHeader=pd.read_csv(data_path,header=None)
loan_data_withoutHeader.head()
# Out:
#    0                    1                          2   \
# 0  ID  Income_of_Applicant  Income_of_Joint_Applicant
# 1   1                 5849                          0
# 2   2                 4583                       1508
# 3   3                 3000                          0
# 4   4                 2583                       2358
#
#                         3                 4               5       6   \
# 0  Loan_Amount_Requirement  Loan_Amount_Term  Credit_History  Gender
# 1                      NaN               360               1    Male
# 2                      128               360               1    Male
# 3                       66               360               1    Male
# 4                      120               360               1    Male
#
#            7                 8                   9                 10  \
# 0  Is_Married  No_of_Dependents  Level_of_Education  IS_Self_Employed
# 1          No                 0            Graduate                No
# ...

# %% [markdown]
# ### make first row as header

# %%
header=loan_data_withoutHeader.iloc[0]
df=loan_data_withoutHeader[1:]
df.columns=header
df.head()
# Out:
# 0 ID Income_of_Applicant Income_of_Joint_Applicant Loan_Amount_Requirement  \
# 1  1                5849                         0                     NaN
# 2  2                4583                      1508                     128
# 3  3                3000                         0                      66
# 4  4                2583                      2358                     120
# 5  5                6000                         0                     141
#
# 0 Loan_Amount_Term Credit_History Gender Is_Married No_of_Dependents  \
# 1              360              1   Male         No                0
# 2              360              1   Male        Yes                1
# 3              360              1   Male        Yes                0
# 4              360              1   Male        Yes                0
# 5              360              1   Male         No                0
#
# 0 Level_of_Education IS_Self_Employed Area_of_Property Loan_Status
# ...

# %% [markdown]
# ### columns returns all the columns names in your dataframe

# %%
loanData.columns
# Out:
# Index(['ID', 'Income_of_Applicant', 'Income_of_Joint_Applicant',
#        'Loan_Amount_Requirement', 'Loan_Amount_Term', 'Credit_History',
#        'Gender', 'Is_Married', 'No_of_Dependents', 'Level_of_Education',
#        'IS_Self_Employed', 'Area_of_Property', 'Loan_Status'],
#       dtype='object')

# %% [markdown]
# ## By default, the dropna() method returns a new DataFrame, and will not change the original.
# ###  Note : If you want to change the original DataFrame, use the inplace = True argument

# %%
removed_null_data=loanData.dropna()
#loanData.dropna(inplace = True)  This line will change the original dataframe
